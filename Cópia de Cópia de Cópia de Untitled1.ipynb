# %%
 

Polegadas = input("digite um valor em polegadas:")
print(float(Polegadas)* 25.4)

 

raio = input("digite o raio:")
altura = input("digite a altura:")
volume  = (float(3.14)*(float(raio)**2)*float(altura))
print(volume)



nota_1 = input("Digite a nota 1")
nota_2 = input("Digite a nota 2")
nota_3 = input("Digite a nota 3")
media = (((float(nota_1)*2)+(float(nota_2)*3)+(float(nota_3)*5)) / 10)
print("Sua nota final será", media)




salariobruto = input("digite o valor do salario bruto: ")
IR = float(salariobruto) * 0.15
INSS = float(salariobruto)* 0.11
Sindicato = float(salariobruto) * 0.03
ValorLiquido = float(salariobruto) - IR - INSS - Sindicato

print("O valor do salario bruto é: ", salariobruto)
print("O valor do IR é: ",IR)
print("O valor do INSS é:",INSS)
print("O valor do sindicato é: ",Sindicato)
print("O valor do salário liquido é:", ValorLiquido)



distancia = input("digite o valor da distancia em KM:")
consumodocarro = input("digite o consumo:")
precogasolina = input("digite o preço da gasolina por litro:")
litros = float(distancia) / float(consumodocarro)
gasto = float(litros) * float(precogasolina)

print("o valos gasto é: " , gasto)
print("são precisos" ,litros , "litros de gasolina")
# Out:
# digite um valor em polegadas:10
# 254.0
# digite o raio:5
# digite a altura:10
# 785.0
# Digite a nota 110
# Digite a nota 28
# Digite a nota 34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# ...

# %%
distancia = input("digite o valor da distancia em KM:")
consumodocarro = input("digite o consumo:")
precogasolina = input("digite o preço da gasolina por litro:")
litros = float(distancia) / float(consumodocarro)
gasto = float(litros) * float(precogasolina)

print("o valos gasto é: " , gasto)
print("são precisos" ,litros , "litros de gasolina")
# Out:
# digite o valor da distancia em KM:1000
# digite o consumo:50
# digite o preço da gasolina por litro:5
# o valos gasto é:  100.0
# são precisos 20.0 litros de gasolina
